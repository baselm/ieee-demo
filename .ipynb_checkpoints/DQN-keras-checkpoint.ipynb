# %%
from __future__ import division, print_function, unicode_literals
import csv
import shutil
import os
import time
import requests
import subprocess
from subprocess import call
import numpy as np
import tensorflow as tf

# %%
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [markdown]
# # # # MDP

# %% [markdown]
# ## Deep Q-Learning

# %%
import gym
import gym_foo

# %%
env = gym.make('foo-v13')
# Out:
# __init__

# %%
env.observation_space.shape
# Out:
# (4, 5)

# %%
nb_actions= env.action_space.n
nb_actions
# Out:
# 6

# %%
env.node
# Out:
# 1

# %%
# Next, we build a very simple model.
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                336
# _________________________________________________________________
# activation_5 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                272
# _________________________________________________________________
# activation_6 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# activation_7 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 102
# _________________________________________________________________
# activation_8 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 982
# Trainable params: 982
# Non-trainable params: 0
# _________________________________________________________________

# %%
memory = SequentialMemory(limit=1000, window_length=1)
policy = BoltzmannQPolicy()
dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=10,
               target_model_update=1e-2, policy=policy)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

# %%
# %%time
dqn.fit(env, nb_steps=100, visualize=False, verbose=2)
# Out:
# Training for 100 steps ...
# [[11.99464737 11.99464737  1.          0.5         0.        ]
#  [35.23321414 35.23321414  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.6        61.6         1.          0.5         0.        ]]
# Stay in State S0
# [[12.73051849 12.73051849  1.          0.5         0.        ]
#  [35.23874164 35.23874164  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 8.          8.          1.          0.5         0.        ]]
# Delete Node with attempt:  2
# reward:  0.5 0.0 1.0
# [[12.73051849 12.73051849  1.          0.5         0.        ]
#  [35.23874164 35.23874164  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 8.          8.          1.          0.5         0.        ]]
# Scale Down Move to State S1
# {'previous_replicas': '3', 'result': 'Service converged', 'Replicas': '2'}
# 0.5
#   3/100: episode: 1, duration: 36.841s, episode steps: 3, steps per second: 0, episode reward: 1.500, mean reward: 0.500 [0.000, 1.000], mean action: 3.000 [0.000, 5.000], mean observation: 58.565 [0.000, 1176.163], loss: --, mean_absolute_error: --, mean_q: --
# [[11.06061575 11.06061575  1.          0.5         0.        ]
#  [35.27715677 35.27715677  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 8.          8.          1.          0.5         0.        ]]
# Delete Node with attempt:  4
# reward:  0.5 0.0 1.0
# [[10.84858189 10.84858189  1.          0.5         0.        ]
#  [35.31040537 35.31040537  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [79.96179889 79.96179889  1.          0.5         0.        ]]
# Delete Node with attempt:  5
# reward:  0.5 0.0 1.0
# [[10.84858189 10.84858189  1.          0.5         0.        ]
#  [35.31040537 35.31040537  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 8.          8.          1.          0.5         0.        ]]
# Add Node S4
# /Users/baz/ieee-demo/addNode.sh

# %%
# Okay, now it's time to learn something! We visualize the training here for show, but this
# slows down training quite a lot. You can always safely abort the training prematurely using
# Ctrl + C.
ENV_NAME="micro2"
dqn.fit(env, nb_steps=1000, visualize=True, verbose=2)

# After training is done, we save the final weights.
dqn.save_weights('dqn_{}_weights.h5f'.format(ENV_NAME), overwrite=True)

# Finally, evaluate our algorithm for 5 episodes.
dqn.test(env, nb_episodes=5, visualize=True)
# Out:
# Training for 1000 steps ...
# [[ 8.71414693  8.71414693  1.          0.5         0.        ]
#  [33.86379767 33.86379767  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [68.4045603  68.4045603   1.          0.5         0.        ]]
# Scale Down Move to State S1
# 0.5
# WARN: View is not allowed in this environment
# [[  8.71414693   8.71414693   1.           0.5          0.        ]
#  [ 33.86379767  33.86379767   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [124.45648267 124.45648267   1.           0.5          0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
# [[1.25656394e+01 1.25656394e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.38172696e+01 3.38172696e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.54459013e+03 1.54459013e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    3/1000: episode: 1, duration: 6.105s, episode steps: 3, steps per second: 0, episode reward: 1.500, mean reward: 0.500 [0.000, 1.000], mean action: 3.000 [2.000, 5.000], mean observation: 14.655 [0.000, 68.405], loss: --, mean_absolute_error: --, mean_q: --
# [[12.56563939 12.56563939  1.          0.5         0.        ]
#  [33.81726965 33.81726965  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    4/1000: episode: 2, duration: 2.661s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 16.699 [0.000, 61.604], loss: --, mean_absolute_error: --, mean_q: --
# [[12.56563939 12.56563939  1.          0.5         0.        ]
#  [33.81726965 33.81726965  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.60410694 61.60410694  1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    5/1000: episode: 3, duration: 2.619s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 644.454 [0.000, 6339.156], loss: --, mean_absolute_error: --, mean_q: --
# [[1.25939388e+01 1.25939388e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.38112486e+01 3.38112486e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.10970118e+03 1.10970118e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    6/1000: episode: 4, duration: 2.661s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 28.882 [0.000, 183.420], loss: --, mean_absolute_error: --, mean_q: --
# [[12.59393884 12.59393884  1.          0.5         0.        ]
#  [33.81124862 33.81124862  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [41.06392907 41.06392907  1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    7/1000: episode: 5, duration: 2.571s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 10.541 [0.000, 56.000], loss: --, mean_absolute_error: --, mean_q: --
# [[12.59393884 12.59393884  1.          0.5         0.        ]
#  [33.81124862 33.81124862  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#    8/1000: episode: 6, duration: 2.403s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 10.541 [0.000, 56.000], loss: --, mean_absolute_error: --, mean_q: --
# [[26.31480395 26.31480395  1.          0.5         0.        ]
#  [33.79863862 33.79863862  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#   43/1000: episode: 14, duration: 5.935s, episode steps: 3, steps per second: 1, episode reward: 1.500, mean reward: 0.500 [0.000, 1.000], mean action: 3.333 [2.000, 4.000], mean observation: 356.974 [0.000, 10233.333], loss: 1067.255981, mean_absolute_error: 16.854977, mean_q: 28.379343
# [[ 25.80423413  25.80423413   1.           0.5          0.        ]
#  [ 33.96150044  33.96150044   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [119.8        119.8          1.           0.5          0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#   44/1000: episode: 15, duration: 2.579s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 894.503 [0.000, 8826.267], loss: 1076.542725, mean_absolute_error: 15.859058, mean_q: 26.950209
# [[25.80423413 25.80423413  1.          0.5         0.        ]
#  [33.96150044 33.96150044  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.6        61.6         1.          0.5         0.        ]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[2.58042341e+01 2.58042341e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.39615004e+01 3.39615004e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.47653333e+03 1.47653333e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[2.58920346e+01 2.58920346e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.38508920e+01 3.38508920e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.47653333e+03 1.47653333e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  26
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[25.89203458 25.89203458  1.          0.5         0.        ]
#  [33.85089201 33.85089201  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.6        61.6         1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#   48/1000: episode: 16, duration: 7.596s, episode steps: 4, steps per second: 1, episode reward: 2.000, mean reward: 0.500 [0.000, 1.000], mean action: 2.000 [1.000, 4.000], mean observation: 386.273 [0.000, 14671.733], loss: 1600.668579, mean_absolute_error: 17.531023, mean_q: 29.196667
# [[25.89203458 25.89203458  1.          0.5         0.        ]
#  [33.85089201 33.85089201  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Delete Node with attempt:  28
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 25.89203458  25.89203458   1.           0.5          0.        ]
#  [ 33.85089201  33.85089201   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [111.2        111.2          1.           0.5          0.        ]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[24.67870036 24.67870036  1.          0.5         0.        ]
#  [33.85918326 33.85918326  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [58.         58.          1.          0.5         0.        ]]
# Delete Node with attempt:  30
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[24.67870036 24.67870036  1.          0.5         0.        ]
#  [33.86204571 33.86204571  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#   52/1000: episode: 17, duration: 7.856s, episode steps: 4, steps per second: 1, episode reward: 2.000, mean reward: 0.500 [0.000, 1.000], mean action: 2.750 [1.000, 4.000], mean observation: 454.666 [0.000, 8826.267], loss: 801.791260, mean_absolute_error: 17.519115, mean_q: 30.864813
# [[24.67870036 24.67870036  1.          0.5         0.        ]
#  [33.86204571 33.86204571  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.59589361 61.59589361  1.          0.5         0.        ]]
# Maintain Cluster State S0
# WARN: View is not allowed in this environment
#   53/1000: episode: 18, duration: 3.037s, episode steps: 1, steps per second: 0, episode reward: 1.000, mean reward: 1.000 [1.000, 1.000], mean action: 2.000 [2.000, 2.000], mean observation: 11.754 [0.000, 56.000], loss: 558.937744, mean_absolute_error: 18.873755, mean_q: 35.541603
# [[2.72253670e+01 2.72253670e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.
1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [64.4        64.4         1.          0.5         0.        ]]
# Delete Node with attempt:  91
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 29.09905635  29.09905635   1.           0.5          0.        ]
#  [ 33.88496754  33.88496754   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [184.33645354 184.33645354   1.           0.5          0.        ]]
# Scale Down Move to State S1
# 0.5
# WARN: View is not allowed in this environment
# [[2.90147932e+01 2.90147932e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.38973885e+01 3.38973885e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
# ...
#  [ 0.          0.          1.          0.5         0.        ]]
# Delete Node with attempt:  2843
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[2.59587004e+01 2.59587004e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.50561930e+01 3.50561930e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.05491333e+04 1.05491333e+04 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  2844
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[2.59587004e+01 2.59587004e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.50561930e+01 3.50561930e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.05491333e+04 1.05491333e+04 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  2845
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 25.98536702  25.98536702   1.           0.5          0.        ]
#  [ 35.05619301  35.05619301   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [146.20355603 146.20355603   1.           0.5          0.        ]]
# Delete Node with attempt:  2846
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[25.97463369 25.97463369  1.          0.5         0.        ]
#  [35.04592765 35.04592765  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Delete Node with attempt:  2847
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[25.97463369 25.97463369  1.          0.5         0.        ]
#  [35.04592765 35.04592765  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Delete Node with attempt:  2848
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[2.59746337e+01 2.59746337e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.50459277e+01 3.50459277e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [9.12053333e+03 9.12053333e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[25.97463369 25.97463369  1.          0.5         0.        ]
#  [35.04592765 35.04592765  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Scale Down Move to State S1
# 0.5
# WARN: View is not allowed in this environment
# [[ 25.04130036  25.04130036   1.           0.5          0.        ]
#  [ 35.034131    35.034131     1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [141.80355603 141.80355603   1.           0.5          0.        ]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[ 25.04130036  25.04130036   1.           0.5          0.        ]
#  [ 35.034131    35.034131     1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [181.53957417 181.53957417   1.           0.5          0.        ]]
# Delete Node with attempt:  2852
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[25.04130036 25.04130036  1.          0.5         0.        ]
#  [35.034131   35.034131    1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Scale Down Move to State S1
# 0.5
# WARN: View is not allowed in this environment
# [[25.65463369 25.65463369  1.          0.5         0.        ]
#  [35.034131   35.034131    1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Scale Service UP S2
# {'previous_replicas': '2', 'result': 'No Adaptation', 'Replicas': '2'}
# 0.5
# WARN: View is not allowed in this environment
# [[2.56386986e+01 2.56386986e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.50353155e+01 3.50353155e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [8.00346690e+03 8.00346690e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  2855
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 25.63869858  25.63869858   1.           0.5          0.        ]
#  [ 35.03531547  35.03531547   1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [119.80265375 119.80265375   1.           0.5          0.        ]]
# Delete Node with attempt:  2856
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[25.02536525 25.02536525  1.          0.5         0.        ]
#  [35.03531547 35.03531547  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Delete Node with attempt:  2857
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[40.89203191 40.89203191  1.          0.5         0.        ]
#  [35.6986735  35.6986735   1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [61.60410694 61.60410694  1.          0.5         0.        ]]
# Delete Node with attempt:  2858
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 40.89203191  40.89203191   1.           0.5          0.        ]
#  [ 35.6986735   35.6986735    1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [137.60028589 137.60028589   1.           0.5          0.        ]]
# Delete Node with attempt:  2859
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[ 41.86796347  41.86796347   1.           0.5          0.        ]
#  [ 35.7004502   35.7004502    1.           0.5          0.        ]
#  [ 56.          56.           1.           0.5          0.        ]
#  [128.59320585 128.59320585   1.           0.5          0.        ]]
# Delete Node with attempt:  2860
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[4.18679635e+01 4.18679635e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.57004502e+01 3.57004502e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.45130325e+03 5.45130325e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  2861
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[4.31479635e+01 4.31479635e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [3.52479901e+01 3.52479901e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [5.60000000e+01 5.60000000e+01 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]
#  [1.12261484e+03 1.12261484e+03 1.00000000e+00 5.00000000e-01
#   0.00000000e+00]]
# Delete Node with attempt:  2862
# reward:  0.5 0.0 1.0
# WARN: View is not allowed in this environment
# [[43.14796347 43.14796347  1.          0.5         0.        ]
#  [35.24799005 35.24799005  1.          0.5         0.        ]
#  [56.         56.          1.          0.5         0.        ]
#  [ 0.          0.          1.          0.5         0.        ]]
# Scale Down Move to State S1
# {'previous_replicas': '2', 'result': 'Service converged', 'Replicas': '3'}
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# /anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0xb32581588>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='192.168.99.100', port=8888): Max retries exceeded with url: /disk (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0xb32581588>: Failed to establish a new connection: [Errno 61] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-29-b75630afcfdd> in <module>
#       9
#      10 # Finally, evaluate our algorithm for 5 episodes.
# ---> 11 dqn.test(env, nb_episodes=5, visualize=True)
#
# /anaconda3/lib/python3.6/site-packages/keras_rl-0.4.2-py3.6.egg/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     347                 for _ in range(action_repetition):
#     348                     callbacks.on_action_begin(action)
# --> 349                     observation, r, d, info = env.step(action)
#     350                     observation = deepcopy(observation)
#     351                     if self.processor is not None:
#
# ~/ieee-demo/gym_foo/gym_foo/envs/foo_env.py in step(self, action)
#      83                 else:
#      84                     done= False
# ---> 85                 self.obs = self.get_observation()
#      86                 reward= 1 - np.amax(self.obs[:,3])
#      87                 print(reward)
#
# ~/ieee-demo/gym_foo/gym_foo/envs/foo_env.py in get_observation(self)
#     209             self.viewer = None
#     210     def get_observation(self):
# --> 211         self.disk_axis = self.get_disk_observation()
#     212         self.mem_axis = self.get_mem_observation()
#     213         self.cpu_axis = self.get_cpu_observation()
#
# ~/ieee-demo/gym_foo/gym_foo/envs/foo_env.py in get_disk_observation(self)
#     251         return np.array(net_axis)
#     252     def get_disk_observation(self):
# --> 253         response = requests.get('http://192.168.99.100:8888/disk', timeout=5)
#     254         if response is not None:
#     255             results = response.json()
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='192.168.99.100', port=8888): Max retries exceeded with url: /disk (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0xb32581588>: Failed to establish a new connection: [Errno 61] Connection refused',))
