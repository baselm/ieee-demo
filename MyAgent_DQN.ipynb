# %%
import gym

# %%
import gym_foo

# %%
env = gym.make('foo-v9')
# Out:
# __init__

# %%
env.cpu_axis
# Out:
# array([13.93945655, 13.93945655,  1.        ,  0.5       ,  6.96972828])

# %%
env.adapte_cpu
# Out:
# False

# %%
action = 1 # accelerate right
obs, reward, done, info = env.step(action)
# Out:
# [[31.6825589  31.6825589   1.          0.5        15.84127945]
#  [51.68475103 51.68475103  1.          0.5        25.84237551]
#  [31.6825589  31.6825589   1.          0.5        15.84127945]
#  [62.11273082 62.11273082  1.          0.5        31.05636541]]
# Scale Service UP S2
# <Response [200]>
# 31.056365409767018

# %%
env.get_observation()
# Out:
# array([[12.75037055, 12.75037055,  1.        ,  0.5       ,  6.37518528],
#        [51.85409945, 51.85409945,  1.        ,  0.5       , 25.92704973],
#        [12.75037055, 12.75037055,  1.        ,  0.5       ,  6.37518528],
#        [96.82592716, 96.82592716,  1.        ,  0.5       , 48.41296358]])

# %%
env.cpu_axis
# Out:
# array([70.93525765, 70.93525765,  1.        ,  0.5       , 35.46762882])

# %%
env.obs
# Out:
# array([[71.13525765, 71.13525765,  1.        ,  0.5       , 35.56762882],
#        [59.43252708, 59.43252708,  1.        ,  0.5       , 29.71626354],
#        [70.93525765, 70.93525765,  1.        ,  0.5       , 35.46762882],
#        [ 0.        ,  0.        ,  1.        ,  0.5       ,  0.        ]])

# %%
import time

# %%
for i in range(10):
   
    time.sleep(2)
    print(env.obs)
    print("========")
    print(env.cpu_axis)
# Out:
# [[1.93315514e+01 1.93315514e+01 1.00000000e+00 5.00000000e-01
#   9.66577570e+00]
#  [5.74453284e+01 5.74453284e+01 1.00000000e+00 5.00000000e-01
#   2.87226642e+01]
#  [1.93315514e+01 1.93315514e+01 1.00000000e+00 5.00000000e-01
#   9.66577570e+00]
#  [3.66266737e+03 3.66266737e+03 1.00000000e+00 5.00000000e-01
#   1.83133369e+03]]
# ...
# [19.3315514 19.3315514  1.         0.5        9.6657757]
# [[1.93315514e+01 1.93315514e+01 1.00000000e+00 5.00000000e-01
#   9.66577570e+00]
#  [5.74453284e+01 5.74453284e+01 1.00000000e+00 5.00000000e-01
#   2.87226642e+01]
#  [1.93315514e+01 1.93315514e+01 1.00000000e+00 5.00000000e-01
#   9.66577570e+00]
#  [3.66266737e+03 3.66266737e+03 1.00000000e+00 5.00000000e-01
#   1.83133369e+03]]
# ...
# [19.3315514 19.3315514  1.         0.5        9.6657757]
# [[1.93315514e+01 1.93315514e+01 1.00000000e+00 5.00000000e-01
#   9.66577570e+00]
#  [5.74453284e+01 5.74453284e+01 1.00000000e+00 5.00000000e-01
#   2.87226642e+01]
# ...
